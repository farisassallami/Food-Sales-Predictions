# %% [markdown]
# <a href="https://colab.research.google.com/github/farisassallami/Food-Sales-Predictions/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Faris Assallami

# %% [markdown]
# ### Loading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/sales_predictions.csv')
df.info()
df.head()

print(df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
# Removing columns that contain irrelevant data
df = df.drop(columns=['Item_Identifier', 'Item_Weight','Outlet_Establishment_Year'])

df.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0            OUT049      Medium               Tier 1  Supermarket Type1
# 1            OUT018      Medium               Tier 3  Supermarket Type2
# 2            OUT049      Medium               Tier 1  Supermarket Type1
# 3            OUT010         NaN               Tier 3      Grocery Store
# 4            OUT013        High               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
# Question 1

print("After removing 3 irrelevant columns, there are now 8523 rows and 9 columns left")
print()
df.shape
# Out:
# After removing 3 irrelevant columns, there are now 8523 rows and 9 columns left
# (8523, 9)

# %%
# Question 2
df.info()
print()
print()
print()
print("((--------The data types of each variable are float64, int64 and object--------))")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Fat_Content      8523 non-null   object
#  1   Item_Visibility       8523 non-null   float64
#  2   Item_Type             8523 non-null   object
#  3   Item_MRP              8523 non-null   float64
#  4   Outlet_Identifier     8523 non-null   object
#  5   Outlet_Size           6113 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Outlet_Type           8523 non-null   object
#  8   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 599.4+ KB
#
#
#
# ((--------The data types of each variable are float64, int64 and object--------))

# %%
# Question 3
print(df.duplicated().any())
print("There are no duplicates.")
# Out:
# False
# There are no duplicates.

# %%
# Question 4
print(df.isna().sum())
print()
print("There are 2410 missing values in the Outlet_Size column ")
print()
print()


df[df.isna().any(axis=1)]
print()
print()
print(df['Outlet_Size'].value_counts())
print()
print()
# Out:
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64
#
# There are 2410 missing values in the Outlet_Size column
#
#
#
#
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# Question 5
print("Based on the data available in the Outlet_Size column,\n I will use the Medium value to fill in the missing values since its the highest appearing value.")


modeSize = str(df["Outlet_Size"].mode())
print()
df['Outlet_Size'].fillna(value = modeSize, inplace = True)
print(modeSize)
# Out:
# Based on the data available in the Outlet_Size column,
#  I will use the Medium value to fill in the missing values since its the highest appearing value.
#
# 0    Medium
# dtype: object

# %%
# Question 6
print(df.isna().sum())
print()
print("The Outlet_Size column no longer has missing values as seen in the chart above.")
# Out:
# Item_Fat_Content        0
# Item_Visibility         0
# Item_Type               0
# Item_MRP                0
# Outlet_Identifier       0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# dtype: int64
#
# The Outlet_Size column no longer has missing values as seen in the chart above.

# %%
# Question 7
print(df["Item_Fat_Content"].value_counts())
print()
print("--Inconsistent categories fount in Item_Fat_Content column.\n LF and low fat will be corrected to Low Fat, and reg will be corrected to Regular")
print()

df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF', 'Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat', 'Low Fat')

df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg', 'Regular')

print(df["Item_Fat_Content"].value_counts())
print()
print("--All inconsistencies have been corrected.")
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# --Inconsistent categories fount in Item_Fat_Content column.
#  LF and low fat will be corrected to Low Fat, and reg will be corrected to Regular
#
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64
#
# --All inconsistencies have been corrected.

# %%
df
# Out:
#      Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0             Low Fat         0.016047                  Dairy  249.8092
# 1             Regular         0.019278            Soft Drinks   48.2692
# 2             Low Fat         0.016760                   Meat  141.6180
# 3             Regular         0.000000  Fruits and Vegetables  182.0950
# 4             Low Fat         0.000000              Household   53.8614
# ...               ...              ...                    ...       ...
# 8518          Low Fat         0.056783            Snack Foods  214.5218
# 8519          Regular         0.046982           Baking Goods  108.1570
# 8520          Low Fat         0.035186     Health and Hygiene   85.1224
# 8521          Regular         0.145221            Snack Foods  103.1332
# 8522          Low Fat         0.044878            Soft Drinks   75.4670
#
#      Outlet_Identifier                 Outlet_Size Outlet_Location_Type  \
# 0               OUT049                      Medium               Tier 1
# 1               OUT018                      Medium               Tier 3
# 2               OUT049                      Medium               Tier 1
# 3               OUT010  0    Medium\ndtype: object               Tier 3
# 4               OUT013                        High               Tier 3
# ...                ...                         ...                  ...
# 8518            OUT013                        High               Tier 3
# 8519            OUT045  0    Medium\ndtype: object               Tier 2
# 8520            OUT035                       Small               Tier 2
# 8521            OUT018                      Medium               Tier 3
# 8522            OUT046                       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 9 columns]

# %%
# Question 8

statistics =  df.describe()
statistics.loc[['mean','min','max']]
# Out:
#       Item_Visibility    Item_MRP  Item_Outlet_Sales
# mean         0.066132  140.992782        2181.288914
# min          0.000000   31.290000          33.290000
# max          0.328391  266.888400       13086.964800
